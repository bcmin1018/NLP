# %% [markdown]
# <a href="https://colab.research.google.com/github/bcmin1018/NLP/blob/main/Classification/Sentiment_Analysis/%EC%98%81%ED%99%94%EB%A6%AC%EB%B7%B0%EA%B0%90%EC%84%B1%EB%B6%84%EC%84%9D/Mecab%2BbiLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys 
from google.colab import drive
drive.mount('/content/drive')

import torch
import torchvision
import torch.nn
torch.cuda.is_available()
# Out:
# Mounted at /content/drive
# True

# %%
# Colab Mecab install
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh > /dev/null
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 18.85 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# --2022-05-26 10:48:27--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::6b17:d1f5, 2406:da00:ff00::22e9:9f55, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=UX9iJkNKKnkgm%2FkU0sExKEvsP68%3D&Expires=1653563908&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None [following]
# --2022-05-26 10:48:28--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=UX9iJkNKKnkgm%2FkU0sExKEvsP68%3D&Expires=1653563908&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 54.231.204.241
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|54.231.204.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  --.-KB/s    in 0.1s
#
# 2022-05-26 10:48:28 (11.3 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# --2022-05-26 10:49:45--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::6b17:d1f5, 2406:da00:ff00::22e9:9f55, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=YcD5uiffKdhdIOqXf%2FefGslgbVo%3D&Expires=1653563985&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None [following]
# --2022-05-26 10:49:45--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=YcD5uiffKdhdIOqXf%2FefGslgbVo%3D&Expires=1653563985&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.113.115
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.113.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  91.2MB/s    in 0.5s
#
# 2022-05-26 10:49:46 (91.2 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from konlpy.tag import Mecab
from konlpy.tag import Okt
from collections import Counter

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Embedding, Dense, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
DIR = '/content/drive/MyDrive/project/영화 리뷰 감성 분석/dataset'
TRAIN_SOURCE = os.path.join(DIR, "train.csv")
TEST_SOURCE = os.path.join(DIR, "test.csv")
SAMPLE_SUBMISSION = os.path.join(DIR, "sample_submission.csv")

train = pd.read_csv(TRAIN_SOURCE)
test = pd.read_csv(TEST_SOURCE)
print("train row : {}, train col : {}".format(str(train.shape[0]), str(train.shape[1])))
print("test row : {}, test col : {}".format(str(test.shape[0]), str(test.shape[1])))
# Out:
# train row : 5000, train col : 3
# test row : 5000, test col : 2

# %%
# 한글 외에 모든 문자 제거
train['preprocessed'] = train['document'].str.replace("[^A-Za-zㄱ-ㅎㅏ-ㅣ가-힣 ]","") 

# 다중 공백 제거
train['preprocessed'] = train['preprocessed'].str.replace(" +", " ")

# %%
# 네이버 맞춤법 체크 (쥬피터에서 진행)
train = pd.read_csv('/content/drive/MyDrive/project/영화 리뷰 감성 분석/dataset/spell_chk_train.csv')
test = pd.read_csv('/content/drive/MyDrive/project/영화 리뷰 감성 분석/dataset/spell_chk_test.csv')

# %%
train
# Out:
#       Unnamed: 0  ...                             spell_checked
# 0              0  ...                영상이나 음악이 이쁘다 해도 미화시킨 불륜일 뿐
# 1              1  ...                히치콕이 이 영화를 봤다면 분명 손뼉을 쳤을 듯
# 2              2  ...          괜찮은 음악영화가 또 나왔군요 따뜻한 겨울이 될 것 같아요
# 3              3  ...            아무래도 연도 지난 작품이라 지금 보기는 너무 유치하다
# 4              4  ...     지금까지의 영화들이 그랬듯이 영화 역시 일본에 대한 미화는 여전하다
# ...          ...  ...                                       ...
# 4995        4995  ...                  좋은 배우들로 류 양화를 찍은 안타까운 영화
# 4996        4996  ...  진짜 더럽게 재미없다 에드워드 호퍼 그림에 배경 빼고는 볼 게 아닌 영화
# 4997        4997  ...                   가장 실망스러운 영화 지금까지 본 영화 중
# 4998        4998  ...             이런 평점 테러 네이버에서 좀 막아야 하는 것 아닌가
# 4999        4999  ...         여주인공이 전작에서는 귀여웠는데 여기선 정말 망했네 실망이다
#
# [5000 rows x 6 columns]

# %%
# okt = Okt()
# tokenized = []
# for sentence in train['spell_checked']:
#     tokens = okt.morphs(sentence, stem = True)
#     tokenize = " ".join(tokens)
#     tokenized.append(tokenize)
# train["tokenized_stem"] = pd.DataFrame(tokenized)

# %%
mecab = Mecab()

#품사별로 컬럼 나눌때
# Noun_pos = []
# Verb_pos = []
# Adjective_pos = []

# for sentence in train['tokenized_stem']:
#   pos = mecab.pos(sentence)
#   Noun_pos_tmp = [word_pos[0] for word_pos in pos if word_pos[1] in ("NNG", "NNP")]
#   Noun_pos_tmp = " ".join(Noun_pos_tmp)
#   Noun_pos.append(Noun_pos_tmp)

#   Verb_pos_tmp = [word_pos[0] for word_pos in pos if word_pos[1] in ("VV")]
#   Verb_pos_tmp = " ".join(Verb_pos_tmp)
#   Verb_pos.append(Verb_pos_tmp)

#   Adjective_pos_tmp = [word_pos[0] for word_pos in pos if word_pos[1] in ("VA")]
#   Adjective_pos_tmp = " ".join(Adjective_pos_tmp)
#   Adjective_pos.append(Adjective_pos_tmp)

# train["Noun_pos"] = pd.DataFrame(Noun_pos)
# train["Verb_pos"] = pd.DataFrame(Verb_pos)
# train["Adjective_pos"] = pd.DataFrame(Adjective_pos)


# 대상 품사를 한 컬럼에
# def pos_extract(doc):
#   pos = mecab.pos(doc)
#   main_word = [word_pos[0] for word_pos in pos if word_pos[1] in ('VV', 'VA', 'MAG', 'XR', 'IC', 'VCN', 'VCP')]
#   return main_word

# %%
# train['main_pos'] = train['spell_checked'].apply(pos_extract)
# test['main_pos'] = test['spell_checked'].apply(pos_extract)

# %%
mecab.pos(train['spell_checked'][0])
# Out:
# [('영상', 'NNG'),
#  ('이나', 'JC'),
#  ('음악', 'NNG'),
#  ('이', 'JKS'),
#  ('이쁘', 'VA'),
#  ('다', 'EC'),
#  ('해도', 'VV+EC'),
#  ('미', 'NNG'),
#  ('화', 'XSN'),
#  ('시킨', 'XSV+ETM'),
#  ('불륜', 'NNG'),
#  ('일', 'VCP+ETM'),
#  ('뿐', 'NNB')]

# %%
# 형태소 추출
train['mecab_morphs'] = train.spell_checked.apply(mecab.morphs)
test['mecab_morphs'] = test.spell_checked.apply(mecab.morphs)

# %%
train
# Out:
#       Unnamed: 0  ...                                       mecab_morphs
# 0              0  ...     [영상, 이나, 음악, 이, 이쁘, 다, 해도, 미, 화, 시킨, 불륜, 일, 뿐]
# 1              1  ...      [히치콕, 이, 이, 영화, 를, 봤, 다면, 분명, 손뼉, 을, 쳤, 을, 듯]
# 2              2  ...  [괜찮, 은, 음악, 영화, 가, 또, 나왔, 군요, 따뜻, 한, 겨울, 이, 될,...
# 3              3  ...  [아무래도, 연도, 지난, 작품, 이, 라, 지금, 보, 기, 는, 너무, 유치, ...
# 4              4  ...  [지금, 까지, 의, 영화, 들, 이, 그랬, 듯이, 영화, 역시, 일본, 에, 대...
# ...          ...  ...                                                ...
# 4995        4995  ...         [좋, 은, 배우, 들, 로, 류, 양화, 를, 찍, 은, 안타까운, 영화]
# 4996        4996  ...  [진짜, 더럽, 게, 재미없, 다, 에드워드, 호퍼, 그림, 에, 배경, 빼, 고,...
# 4997        4997  ...                [가장, 실망, 스러운, 영화, 지금, 까지, 본, 영화, 중]
# 4998        4998  ...      [이런, 평점, 테러, 네이버, 에서, 좀, 막, 아야, 하, 는, 것, 아닌가]
# 4999        4999  ...  [여주인공, 이, 전작, 에서, 는, 귀여웠, 는데, 여기, 선, 정말, 망했, 네...
#
# [5000 rows x 7 columns]

# %%
# 불용어 제거
stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게']
train['remove_stopword'] = train.mecab_morphs.apply(lambda x: [item for item in x if item not in stopwords])
test['remove_stopword'] = test.mecab_morphs.apply(lambda x: [item for item in x if item not in stopwords])

# %%
train
# Out:
#       Unnamed: 0  ...                                remove_stopword
# 0              0  ...       [영상, 이나, 음악, 이쁘, 해도, 미, 화, 시킨, 불륜, 일, 뿐]
# 1              1  ...                    [히치콕, 영화, 봤, 다면, 분명, 손뼉, 쳤]
# 2              2  ...   [괜찮, 음악, 영화, 또, 나왔, 군요, 따뜻, 겨울, 될, 것, 같, 아요]
# 3              3  ...        [아무래도, 연도, 지난, 작품, 라, 지금, 보, 기, 너무, 유치]
# 4              4  ...   [지금, 까지, 영화, 그랬, 듯이, 영화, 역시, 일본, 대한, 미화, 여전]
# ...          ...  ...                                            ...
# 4995        4995  ...                 [좋, 배우, 로, 류, 양화, 찍, 안타까운, 영화]
# 4996        4996  ...  [진짜, 더럽, 재미없, 에드워드, 호퍼, 그림, 배경, 빼, 볼, 아닌, 영화]
# 4997        4997  ...            [가장, 실망, 스러운, 영화, 지금, 까지, 본, 영화, 중]
# 4998        4998  ...        [이런, 평점, 테러, 네이버, 에서, 좀, 막, 아야, 것, 아닌가]
# 4999        4999  ...     [여주인공, 전작, 에서, 귀여웠, 는데, 여기, 선, 정말, 망했, 실망]
#
# [5000 rows x 8 columns]

# %%
X_train = train['remove_stopword']
X_test = test['remove_stopword']
y_train = train.label

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
tokenizer.word_index
# Out:
# {'영화': 1,
#  '보': 2,
#  '없': 3,
#  '좋': 4,
#  '너무': 5,
#  '재밌': 6,
#  '정말': 7,
#  '봤': 8,
#  '었': 9,
#  '있': 10,
#  '나': 11,
#  '는데': 12,
#  '만': 13,
#  '음': 14,
#  '네요': 15,
#  '적': 16,
#  '진짜': 17,
#  '최고': 18,
#  '안': 19,
#  '로': 20,
#  '아': 21,
#  '어': 22,
#  '지만': 23,
#  '것': 24,
#  '했': 25,
#  '기': 26,
#  '았': 27,
#  '으로': 28,
#  '수': 29,
#  '거': 30,
#  '내': 31,
#  '연기': 32,
#  '왜': 33,
#  '말': 34,
#  '같': 35,
#  '점': 36,
#  '이런': 37,
#  '않': 38,
#  '평점': 39,
#  '되': 40,
#  '어요': 41,
#  '잘': 42,
#  '던': 43,
#  '에서': 44,
#  '지루': 45,
#  '면': 46,
#  '감동': 47,
#  '겠': 48,
#  'ㅋㅋ': 49,
#  '할': 50,
#  '재미없': 51,
#  '재미있': 52,
#  '주': 53,
#  '중': 54,
#  '싶': 55,
#  '본': 56,
#  '재미': 57,
#  '드라마': 58,
#  '배우': 59,
#  '해': 60,
#  '뭐': 61,
#  '좀': 62,
#  'ㅋㅋㅋ': 63,
#  '스토리': 64,
#  '습니다': 65,
#  '볼': 66,
#  '시간': 67,
#  '보다': 68,
#  '때': 69,
#  '그냥': 70,
#  '내용': 71,
#  '그': 72,
#  '더': 73,
#  '함': 74,
#  '만들': 75,
#  '까지': 76,
#  '아니': 77,
#  '감독': 78,
#  '냐': 79,
#  '생각': 80,
#  '최악': 81,
#  '사랑': 82,
#  '사람': 83,
#  '번': 84,
#  '이렇게': 85,
#  '못': 86,
#  '알': 87,
#  '다시': 88,
#  '아깝': 89,
#  '이거': 90,
#  '서': 91,
#  '액션': 92,
#  '라': 93,
#  '남': 94,
#  '하나': 95,
#  '끝': 96,
#  '였': 97,
#  '입니다': 98,
#  '해서': 99,
#  '기대': 100,
#  '이야기': 101,
#  '나오': 102,
#  '야': 103,
#  '작품': 104,
#  '봐도': 105,
#  '모르': 106,
#  '이게': 107,
#  '돈': 108,
#  '참': 109,
#  '건': 110,
#  '정도': 111,
#  '쓰레기': 112,
#  '전': 113,
#  '마지막': 114,
#  '명작': 115,
#  '줄': 116,
#  '별로': 117,
#  '년': 118,
#  '이건': 119,
#  '코미디': 120,
#  '다가': 121,
#  '기억': 122,
#  '라고': 123,
#  '면서': 124,
#  '많이': 125,
#  '처음': 126,
#  '자': 127,
#  '또': 128,
#  '분': 129,
#  '다는': 130,
#  '잼': 131,
#  '요': 132,
#  '으면': 133,
#  '일': 134,
#  '역시': 135,
#  '니': 136,
#  '개': 137,
#  '가슴': 138,
#  '합니다': 139,
#  '완전': 140,
#  '이해': 141,
#  '지금': 142,
#  '님': 143,
#  '장면': 144,
#  '두': 145,
#  '많': 146,
#  '인생': 147,
#  '굿': 148,
#  '이상': 149,
#  '편': 150,
#  '인데': 151,
#  '꼭': 152,
#  '난': 153,
#  '소재': 154,
#  '한국': 155,
#  '느낌': 156,
#  '낮': 157,
#  '라는': 158,
#  'ㅎㅎ': 159,
#  '된': 160,
#  '별': 161,
#  '에게': 162,
#  '부터': 163,
#  '엔': 164,
#  '어서': 165,
#  '무슨': 166,
#  '음악': 167,
#  '세요': 168,
#  '긴': 169,
#  '실망': 170,
#  '아요': 171,
#  '필요': 172,
#  '연출': 173,
#  '괜찮': 174,
#  '때문': 175,
#  '아이': 176,
#  '만든': 177,
#  '걸': 178,
#  '속': 179,
#  '오': 180,
#  '성': 181,
#  '뿐': 182,
#  '결말': 183,
#  '우리': 184,
#  '다고': 185,
#  '신': 186,
#  '유치': 187,
#  '원작': 188,
#  '마음': 189,
#  '공포': 190,
#  'ㅡㅡ': 191,
#  '애': 192,
#  '그리고': 193,
#  '은데': 194,
#  '여자': 195,
#  '이나': 196,
#  'ㅋ': 197,
#  '가장': 198,
#  '매력': 199,
#  '시': 200,
#  '시리즈': 201,
#  '현실': 202,
#  '받': 203,
#  '한다': 204,
#  '비': 205,
#  '저': 206,
#  '짜증': 207,
#  '내내': 208,
#  '는지': 209,
#  '주인공': 210,
#  '만드': 211,
#  '길': 212,
#  '여운': 213,
#  '찍': 214,
#  '수준': 215,
#  '아까운': 216,
#  '을까': 217,
#  '다른': 218,
#  '인지': 219,
#  '아직': 220,
#  '아서': 221,
#  '급': 222,
#  '건지': 223,
#  '계속': 224,
#  '높': 225,
#  '웃기': 226,
#  '몇': 227,
#  '일본': 228,
#  '후': 229,
#  '잔잔': 230,
#  '따뜻': 231,
#  '추천': 232,
#  '나름': 233,
#  '뭔가': 234,
#  '려고': 235,
#  '데': 236,
#  '전혀': 237,
#  '다니': 238,
#  'ㅠㅠ': 239,
#  '대': 240,
#  '없이': 241,
#  '죽': 242,
#  '란': 243,
#  '모두': 244,
#  '대단': 245,
#  '웃': 246,
#  '솔직히': 247,
#  '이걸': 248,
#  '제일': 249,
#  '표현': 250,
#  '그래도': 251,
#  '용': 252,
#  '강추': 253,
#  '남자': 254,
#  '반전': 255,
#  '봐야': 256,
#  '마': 257,
#  '살': 258,
#  '대한': 259,
#  '아름다운': 260,
#  '그렇': 261,
#  '눈물': 262,
#  '자체': 263,
#  '캐릭터': 264,
#  '넘': 265,
#  '맞': 266,
#  '는다': 267,
#  '씨': 268,
#  '엔딩': 269,
#  '전개': 270,
#  '랑': 271,
#  '스럽': 272,
#  '짱': 273,
#  '해도': 274,
#  '긴장감': 275,
#  '배경': 276,
#  '구나': 277,
#  '졸작': 278,
#  '죠': 279,
#  '멋있': 280,
#  '보이': 281,
#  '기분': 282,
#  '싫': 283,
#  '스러운': 284,
#  '삶': 285,
#  '라도': 286,
#  '제목': 287,
#  '못하': 288,
#  '스릴러': 289,
#  '인간': 290,
#  '재': 291,
#  '다면': 292,
#  '될': 293,
#  'ᄏᄏ': 294,
#  '며': 295,
#  '쓰': 296,
#  '연기력': 297,
#  '점수': 298,
#  '아주': 299,
#  '울': 300,
#  '아쉽': 301,
#  '대박': 302,
#  '제': 303,
#  '무섭': 304,
#  '화': 305,
#  '작': 306,
#  '함께': 307,
#  '당시': 308,
#  '해요': 309,
#  '밖에': 310,
#  '형': 311,
#  '시나리오': 312,
#  '빼': 313,
#  '부족': 314,
#  '이것': 315,
#  '엄청': 316,
#  '코믹': 317,
#  '첨': 318,
#  '수작': 319,
#  '몰입': 320,
#  '준': 321,
#  '처럼': 322,
#  'oo': 323,
#  '귀엽': 324,
#  '이제': 325,
#  '비디오': 326,
#  '찾': 327,
#  '오랜만': 328,
#  '모든': 329,
#  '딱': 330,
#  '아닌': 331,
#  '극장': 332,
#  '인가': 333,
#  '된다': 334,
#  '대체': 335,
#  '영상': 336,
#  '나왔': 337,
#  '차라리': 338,
#  '의미': 339,
#  '힘들': 340,
#  '예술': 341,
#  '너무나': 342,
#  '추억': 343,
#  '눈': 344,
#  '개봉': 345,
#  '어릴': 346,
#  'ㅎ': 347,
#  '졸': 348,
#  '어디': 349,
#  '라니': 350,
#  'b': 351,
#  '어색': 352,
#  '사': 353,
#  '만화': 354,
#  '시대': 355,
#  '막장': 356,
#  '이유': 357,
#  '억지': 358,
#  '궁금': 359,
#  '어이없': 360,
#  '행복': 361,
#  '먹': 362,
#  '타임': 363,
#  'tv': 364,
#  '난다': 365,
#  '허접': 366,
#  '이랑': 367,
#  '팬': 368,
#  '공감': 369,
#  '이쁘': 370,
#  '걸작': 371,
#  '유쾌': 372,
#  '물': 373,
#  '진심': 374,
#  '애니메이션': 375,
#  '충격': 376,
#  '뭘': 377,
#  '진': 378,
#  '엉성': 379,
#  '놓': 380,
#  '흥미': 381,
#  '됨': 382,
#  '군': 383,
#  '그런': 384,
#  '노': 385,
#  '구성': 386,
#  '더럽': 387,
#  '멋진': 388,
#  'ᄏᄏᄏ': 389,
#  '답': 390,
#  '애니': 391,
#  '시절': 392,
#  '포스터': 393,
#  '던데': 394,
#  '아까워': 395,
#  '시작': 396,
#  '뻔': 397,
#  '초반': 398,
#  '감': 399,
#  '니까': 400,
#  '만큼': 401,
#  '그저': 402,
#  '도대체': 403,
#  '여': 404,
#  '오래': 405,
#  '출연': 406,
#  '근데': 407,
#  '식상': 408,
#  '후회': 409,
#  '깊': 410,
#  '점점': 411,
#  '모습': 412,
#  '반': 413,
#  '머': 414,
#  '신선': 415,
#  '잠': 416,
#  '보여': 417,
#  '아름답': 418,
#  '봐서': 419,
#  '친구': 420,
#  '나온': 421,
#  '글': 422,
#  '너무너무': 423,
#  '개인': 424,
#  '봐': 425,
#  '어떻게': 426,
#  '라서': 427,
#  '가족': 428,
#  '그다지': 429,
#  '맘': 430,
#  '장르': 431,
#  '나올': 432,
#  '로맨틱': 433,
#  '느낄': 434,
#  '위한': 435,
#  '이딴': 436,
#  '소름': 437,
#  '바': 438,
#  '갈수록': 439,
#  '가지': 440,
#  '킬링': 441,
#  '초등학생': 442,
#  '뻔한': 443,
#  '미국': 444,
#  '위': 445,
#  '해야': 446,
#  'ㅠ': 447,
#  '한마디': 448,
#  '그나마': 449,
#  '예요': 450,
#  '대사': 451,
#  '동안': 452,
#  '세계': 453,
#  '욕': 454,
#  '설정': 455,
#  '관객': 456,
#  '치': 457,
#  '어렸': 458,
#  '옛날': 459,
#  'ost': 460,
#  '났': 461,
#  '생': 462,
#  '나요': 463,
#  '생각나': 464,
#  '드': 465,
#  'ㅜㅜ': 466,
#  '전편': 467,
#  '한데': 468,
#  '마다': 469,
#  '봄': 470,
#  '조금': 471,
#  '지루함': 472,
#  '재미나': 473,
#  '슬프': 474,
#  '분위기': 475,
#  '교훈': 476,
#  '굳': 477,
#  '먼': 478,
#  '밋': 479,
#  'ㄷ': 480,
#  '뭔': 481,
#  '그녀': 482,
#  '러': 483,
#  '식': 484,
#  '연대': 485,
#  '스타일': 486,
#  '누가': 487,
#  '제대로': 488,
#  '오늘': 489,
#  '답답': 490,
#  '웃음': 491,
#  '자기': 492,
#  '잔인': 493,
#  '노래': 494,
#  '캐스팅': 495,
#  '어도': 496,
#  '영상미': 497,
#  '언제': 498,
#  '아무': 499,
#  '멋지': 500,
#  '허무': 501,
#  '라면': 502,
#  '아까움': 503,
#  '나라': 504,
#  '군요': 505,
#  '여배우': 506,
#  '잊': 507,
#  '나이': 508,
#  '진부': 509,
#  '떨어지': 510,
#  '네이버': 511,
#  '크': 512,
#  '집': 513,
#  '아님': 514,
#  '자연': 515,
#  '다큐': 516,
#  '마세요': 517,
#  '그래서': 518,
#  '역사': 519,
#  '집중': 520,
#  '삼류': 521,
#  '명': 522,
#  '건가': 523,
#  '왔': 524,
#  '영화관': 525,
#  '사실': 526,
#  'ᅲᅲ': 527,
#  '꽤': 528,
#  '세': 529,
#  '믿': 530,
#  '훨씬': 531,
#  '낸': 532,
#  '의도': 533,
#  '나옴': 534,
#  '버리': 535,
#  '부분': 536,
#  '발': 537,
#  '이름': 538,
#  '놈': 539,
#  '는구나': 540,
#  '어야': 541,
#  '평가': 542,
#  '예전': 543,
#  '감사': 544,
#  '책': 545,
#  '무엇': 546,
#  '존': 547,
#  '아쉬운': 548,
#  '에요': 549,
#  '더니': 550,
#  '짜리': 551,
#  '줬': 552,
#  '여기': 553,
#  '삼': 554,
#  '위해': 555,
#  '길래': 556,
#  '느끼': 557,
#  '업': 558,
#  '약간': 559,
#  '작가': 560,
#  '앞': 561,
#  '큰': 562,
#  '누구': 563,
#  '맛': 564,
#  '비슷': 565,
#  '유': 566,
#  '실화': 567,
#  '한테': 568,
#  '미': 569,
#  '연도': 570,
#  '성장': 571,
#  '절대': 572,
#  '느껴': 573,
#  '전쟁': 574,
#  '스릴': 575,
#  '십': 576,
#  '어린': 577,
#  '이야': 578,
#  '심하': 579,
#  '어설픈': 580,
#  '마저': 581,
#  '그때': 582,
#  '각본': 583,
#  '예쁘': 584,
#  '이하': 585,
#  '평': 586,
#  '대해': 587,
#  '매우': 588,
#  '어쩔': 589,
#  '그대로': 590,
#  '됐': 591,
#  '훌륭': 592,
#  '같이': 593,
#  'ᅳᅳ': 594,
#  '뛰어난': 595,
#  '진정': 596,
#  '산': 597,
#  '프랑스': 598,
#  '별점': 599,
#  '는가': 600,
#  '만점': 601,
#  '심': 602,
#  '류': 603,
#  '역대': 604,
#  '오빠': 605,
#  '장난': 606,
#  '꿀': 607,
#  '시즌': 608,
#  '가볍': 609,
#  '존재': 610,
#  '요즘': 611,
#  '티브이': 612,
#  '나와서': 613,
#  '이후': 614,
#  '얼마나': 615,
#  '빨리': 616,
#  '영': 617,
#  '준다': 618,
#  'ooo': 619,
#  '분명': 620,
#  '리메이크': 621,
#  '성룡': 622,
#  '파이팅': 623,
#  '너': 624,
#  '인물': 625,
#  '인상': 626,
#  '줄거리': 627,
#  '오버': 628,
#  '맞추': 629,
#  '특히': 630,
#  '비교': 631,
#  '시청': 632,
#  '이래': 633,
#  '완벽': 634,
#  '가득': 635,
#  '그래픽': 636,
#  '힘': 637,
#  '땜': 638,
#  '스러움': 639,
#  '편집': 640,
#  '암': 641,
#  '가치': 642,
#  '여주인공': 643,
#  '배': 644,
#  '간다': 645,
#  '얼굴': 646,
#  '바로': 647,
#  '핵': 648,
#  '로맨스': 649,
#  '우': 650,
#  '상': 651,
#  '순수': 652,
#  '흥행': 653,
#  '나온다': 654,
#  '머리': 655,
#  '꽝': 656,
#  '읽': 657,
#  '버린': 658,
#  '더라': 659,
#  '평범': 660,
#  '불쌍': 661,
#  '전형': 662,
#  '질': 663,
#  '간': 664,
#  '흥미진진': 665,
#  '봐라': 666,
#  '선택': 667,
#  '날': 668,
#  'd': 669,
#  '구': 670,
#  '마무리': 671,
#  '리': 672,
#  '다르': 673,
#  '슬픈': 674,
#  '선생': 675,
#  '비추': 676,
#  '비해': 677,
#  '화려': 678,
#  '어떤': 679,
#  '악': 680,
#  '잊히': 681,
#  '점주': 682,
#  '어설프': 683,
#  '귀여워': 684,
#  '미안': 685,
#  '든다': 686,
#  '전부': 687,
#  '봤었': 688,
#  '온': 689,
#  '낭비': 690,
#  '건데': 691,
#  '률': 692,
#  '잖아': 693,
#  '우울': 694,
#  '그만': 695,
#  '로운': 696,
#  '무조건': 697,
#  '중간': 698,
#  '전체': 699,
#  '숨': 700,
#  '돼': 701,
#  '발연기': 702,
#  '냄새': 703,
#  '연출력': 704,
#  '평생': 705,
#  '코': 706,
#  '진실': 707,
#  '돋': 708,
#  '단': 709,
#  '이리': 710,
#  '진다': 711,
#  '충분히': 712,
#  '본다': 713,
#  '상당히': 714,
#  '어렵': 715,
#  '훈훈': 716,
#  '만나': 717,
#  '세상': 718,
#  '독특': 719,
#  '언니': 720,
#  '한심': 721,
#  '주연': 722,
#  '에겐': 723,
#  '조': 724,
#  '얘기': 725,
#  '조차': 726,
#  '웬만': 727,
#  '아야': 728,
#  '빠져': 729,
#  '듦': 730,
#  '허술': 731,
#  '슬픔': 732,
#  '당신': 733,
#  '성공': 734,
#  '메시지': 735,
#  '올해': 736,
#  '로서': 737,
#  '개연': 738,
#  '헐': 739,
#  'ᄒᄒ': 740,
#  '손': 741,
#  '째': 742,
#  '지나': 743,
#  '벌써': 744,
#  '멋': 745,
#  '뒤': 746,
#  '그랬': 747,
#  '나쁘': 748,
#  '마니아': 749,
#  '이따위': 750,
#  '주제': 751,
#  '은지': 752,
#  '으나': 753,
#  '씁쓸': 754,
#  '난해': 755,
#  '환상': 756,
#  '에선': 757,
#  '고요': 758,
#  '과정': 759,
#  '뻔하': 760,
#  '짱짱': 761,
#  '신기': 762,
#  '어쩌': 763,
#  '끌': 764,
#  '보단': 765,
#  '넘치': 766,
#  '속편': 767,
#  '해라': 768,
#  '이젠': 769,
#  '남기': 770,
#  '괜히': 771,
#  '쉽': 772,
#  '텐데': 773,
#  '던가': 774,
#  '결국': 775,
#  '끝나': 776,
#  '뭔지': 777,
#  '제작': 778,
#  '낫': 779,
#  '따라': 780,
#  '담': 781,
#  '어휴': 782,
#  '구먼': 783,
#  '해피': 784,
#  '몰': 785,
#  '오글거리': 786,
#  '순간': 787,
#  '독립영화': 788,
#  '충분': 789,
#  '시키': 790,
#  '못한': 791,
#  '멜': 792,
#  '굉장히': 793,
#  '극': 794,
#  '견자단': 795,
#  '자극': 796,
#  '했었': 797,
#  '잡': 798,
#  '봅니다': 799,
#  'cg': 800,
#  '쯤': 801,
#  '웃긴': 802,
#  '할리우드': 803,
#  '질질': 804,
#  '소장': 805,
#  '무': 806,
#  '그립': 807,
#  '스타': 808,
#  '시사회': 809,
#  '려는': 810,
#  '잼따': 811,
#  '평론가': 812,
#  '서로': 813,
#  '돋보이': 814,
#  'ᄏᄏᄏᄏ': 815,
#  '원': 816,
#  '갔': 817,
#  '외': 818,
#  '나가': 819,
#  'sf': 820,
#  '좋아하': 821,
#  '유머': 822,
#  '비극': 823,
#  '위대': 824,
#  '종교': 825,
#  '나머지': 826,
#  '가끔': 827,
#  '미친': 828,
#  '짐': 829,
#  'ᄏ': 830,
#  '미쳤': 831,
#  '설명': 832,
#  '아마': 833,
#  '전작': 834,
#  '듯이': 835,
#  '즐겁': 836,
#  '기적': 837,
#  '의심': 838,
#  '아무리': 839,
#  '력': 840,
#  '할머니': 841,
#  '땐': 842,
#  '감성': 843,
#  '달달': 844,
#  '낚였': 845,
#  '까': 846,
#  '표절': 847,
#  '그림': 848,
#  '잃': 849,
#  '불': 850,
#  '그렇게': 851,
#  '소소': 852,
#  '성우': 853,
#  '판': 854,
#  '학교': 855,
#  '골': 856,
#  '단순': 857,
#  '다소': 858,
#  '능력': 859,
#  '마이너스': 860,
#  '되게': 861,
#  '예고편': 862,
#  '적당': 863,
#  '짓': 864,
#  '소녀': 865,
#  '예쁜': 866,
#  '결코': 867,
#  '으며': 868,
#  '놔': 869,
#  '빠지': 870,
#  '듣': 871,
#  '엇': 872,
#  '티': 873,
#  '더군요': 874,
#  '여주': 875,
#  '으로서': 876,
#  '맨': 877,
#  '대작': 878,
#  '끝내': 879,
#  '잇': 880,
#  '대한민국': 881,
#  '든': 882,
#  '다운로드': 883,
#  '다음': 884,
#  '즐기': 885,
#  '노력': 886,
#  '미치': 887,
#  '장': 888,
#  '완전히': 889,
#  '취향': 890,
#  '비주얼': 891,
#  '쓴': 892,
#  '어려운': 893,
#  '놀라': 894,
#  '볼수록': 895,
#  '힘든': 896,
#  '려': 897,
#  '다아': 898,
#  '감탄': 899,
#  '영웅': 900,
#  '완성도': 901,
#  '똑같': 902,
#  '어느': 903,
#  '별개': 904,
#  '무서웠': 905,
#  '감정': 906,
#  '입': 907,
#  '생애': 908,
#  '신인': 909,
#  '셨': 910,
#  '제발': 911,
#  '자꾸': 912,
#  '거의': 913,
#  '안타깝': 914,
#  '쇼': 915,
#  '특유': 916,
#  '전달': 917,
#  '그러나': 918,
#  '아프': 919,
#  '게임': 920,
#  '관람': 921,
#  '산만': 922,
#  '예상': 923,
#  '정신': 924,
#  '자유': 925,
#  '대로': 926,
#  '졸라': 927,
#  'ᄒ': 928,
#  '우연히': 929,
#  '그러': 930,
#  '항상': 931,
#  '포장': 932,
#  '둘': 933,
#  '소리': 934,
#  'ᅲ': 935,
#  '볼거리': 936,
#  '을까요': 937,
#  '돼서': 938,
#  '어른': 939,
#  '베스트': 940,
#  '지난': 941,
#  '손가락': 942,
#  '담담': 943,
#  '스포츠': 944,
#  '거지': 945,
#  '상상': 946,
#  '아무것': 947,
#  '소설': 948,
#  '자살': 949,
#  '김': 950,
#  '부': 951,
#  '에로': 952,
#  '댓글': 953,
#  '하지만': 954,
#  '멋져': 955,
#  '연속': 956,
#  '심장': 957,
#  '문제': 958,
#  '더빙': 959,
#  '막': 960,
#  '꿈': 961,
#  '어제': 962,
#  '재능': 963,
#  '풋풋': 964,
#  '뭉클': 965,
#  '굳이': 966,
#  '때리': 967,
#  '카메라': 968,
#  '해석': 969,
#  '알려': 970,
#  '통쾌': 971,
#  '망치': 972,
#  '화면': 973,
#  '추': 974,
#  '이란': 975,
#  '새로운': 976,
#  '어라': 977,
#  '지겹': 978,
#  '여름': 979,
#  '등장': 980,
#  '청춘': 981,
#  '중국': 982,
#  '러브': 983,
#  '은근히': 984,
#  '소중': 985,
#  '중요': 986,
#  '스트레스': 987,
#  '열': 988,
#  '벗': 989,
#  '귀여움': 990,
#  '엉망': 991,
#  '여전히': 992,
#  '아무런': 993,
#  '울리': 994,
#  '팔': 995,
#  '줘야': 996,
#  '몰랐': 997,
#  '겁나': 998,
#  '법': 999,
#  '와서': 1000,
#  ...}

# %%
threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 #등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 #훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 #등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 7191
# 등장 빈도가 1번 이하인 희귀 단어의 수: 4201
# 단어 집합에서 희귀 단어의 비율: 58.42024753163677
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 9.211103315207858

# %%
# 0번 패딩 토큰과 1번 OOV 토큰을 고려하여 +2
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 2992

# %%
# vocab 사전에 없는 단어는 oov로 지정하여 1이라는 숫자를 부여
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
X_train[0]
# Out:
# [337, 197, 168, 371, 275, 570, 306, 1284, 1581, 135, 183]

# %%
print('리뷰의 최대 길이 :',max(len(review) for review in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(review) for review in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 24
# 리뷰의 평균 길이 : 9.1216

# %%
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))

# %%
max_len = 23
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 23 이하인 샘플의 비율: 99.98

# %%
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
X_train
# Out:
# array([[   0,    0,    0, ..., 1581,  135,  183],
#        [   0,    0,    0, ...,  621,    1, 2023],
#        [   0,    0,    0, ...,   25,   36,  172],
#        ...,
#        [   0,    0,    0, ...,   57,    2,   55],
#        [   0,    0,    0, ...,  729,   25, 1023],
#        [   0,    0,    0, ...,    8, 1084,  171]], dtype=int32)

# %%
embedding_dim = 100
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(Bidirectional(LSTM(hidden_units)))
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.5080 - acc: 0.7413
# Epoch 00001: val_acc improved from -inf to 0.84900, saving model to best_model.h5
# 63/63 [==============================] - 10s 39ms/step - loss: 0.5054 - acc: 0.7425 - val_loss: 0.3806 - val_acc: 0.8490
# Epoch 2/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.2607 - acc: 0.8983
# Epoch 00002: val_acc improved from 0.84900 to 0.85100, saving model to best_model.h5
# 63/63 [==============================] - 1s 22ms/step - loss: 0.2616 - acc: 0.8975 - val_loss: 0.3382 - val_acc: 0.8510
# Epoch 3/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.1894 - acc: 0.9283
# Epoch 00003: val_acc did not improve from 0.85100
# 63/63 [==============================] - 1s 22ms/step - loss: 0.1880 - acc: 0.9287 - val_loss: 0.4730 - val_acc: 0.8450
# Epoch 4/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.1463 - acc: 0.9470
# Epoch 00004: val_acc did not improve from 0.85100
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1487 - acc: 0.9457 - val_loss: 0.3876 - val_acc: 0.8200
# Epoch 5/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.1237 - acc: 0.9536
# Epoch 00005: val_acc did not improve from 0.85100
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1231 - acc: 0.9535 - val_loss: 0.4544 - val_acc: 0.8510
# Epoch 6/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.1092 - acc: 0.9629
# Epoch 00006: val_acc did not improve from 0.85100
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1108 - acc: 0.9625 - val_loss: 0.4309 - val_acc: 0.8230
# Epoch 7/15
# 61/63 [============================>.] - ETA: 0s - loss: 0.0875 - acc: 0.9693
# Epoch 00007: val_acc did not improve from 0.85100
# 63/63 [==============================] - 1s 22ms/step - loss: 0.0892 - acc: 0.9685 - val_loss: 0.4777 - val_acc: 0.8400
# Epoch 00007: early stopping

# %%
loaded_model = load_model('best_model.h5')
result = loaded_model.predict(X_test)

# %%
sentiment = []
for i in range(0, len(result)):
  if result[i] > 0.5:
    sentiment.append('1')
  else:
    sentiment.append('0')

# %%
sample_submission = pd.read_csv('/content/drive/MyDrive/project/영화 리뷰 감성 분석/dataset/sample_submission.csv')
sample_submission['label'] = sentiment
sample_submission.to_csv('/content/drive/MyDrive/project/영화 리뷰 감성 분석/etc/sample_submission_biLSTM.csv', index=False)
